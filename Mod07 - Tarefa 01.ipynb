# %% [markdown]
# # Módulo 07, Tarefa 01
#
# Vamos começar a mexer na nossa base de projeto? Já fizemos um exercício de montar a variável resposta, já pudemos perceber que essa atividade pode não ser trivial. Vamos agora trabalhar a base para que fique propícia ao *scikitlearn* para trabalharmos.
#
# Lembrando, a base se chama demo01.csv, e originalmente está publicada [aqui](https://www.kaggle.com/rikdifos/credit-card-approval-prediction).

# %% [markdown]
# #### 1) Carregue a base e avalie:
#
# - As variáveis
# - Tipos de dados de cada variável
# - Quantidade de missings
# - Distribuição da variável resposta (mau)

# %% [markdown]
# ##### 1.1) Importando Bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ##### 1.2) Carregando o DataFrame

# %%
# Carregando base de dados 'demo01.csv'
df = pd.read_csv('demo01.csv')
df_linhas, df_col = df.shape   # Consultando o número de linhas e colunas
print('A base de dados tem', df_linhas,'linhas e', df_col,'colunas')
df.head()
# Out:
# A base de dados tem 16650 linhas e 16 colunas
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    F                N               Y           0  Commercial associate
# 3    M                Y               Y           0               Working
# 4    F                Y               N           0               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# 1  Secondary / secondary special  Single / not married  House / apartment
# 2  Secondary / secondary special  Single / not married  House / apartment
# 3               Higher education               Married  House / apartment
# 4              Incomplete higher               Married  House / apartment
#
# ...

# %%
# Visualizando estrutura da base de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sexo                   16650 non-null  object
#  1   posse_de_veiculo       16650 non-null  object
#  2   posse_de_imovel        16650 non-null  object
#  3   qtd_filhos             16650 non-null  int64
#  4   tipo_renda             16650 non-null  object
#  5   educacao               16650 non-null  object
#  6   estado_civil           16650 non-null  object
#  7   tipo_residencia        16650 non-null  object
#  8   idade                  16650 non-null  float64
#  9   tempo_emprego          16650 non-null  float64
#  10  possui_celular         16650 non-null  int64
#  11  possui_fone_comercial  16650 non-null  int64
#  12  possui_fone            16650 non-null  int64
#  13  possui_email           16650 non-null  int64
# ...

# %% [markdown]
# ###### 1.3)  Visualizando dados do tipo 'Missing'

# %%
# Dados Missing
pd.DataFrame(df.isna().sum(), columns= ['Total de valores missing']).transpose()
# Out:
#                           sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# Total de valores missing     0                 0                0           0
#
#                           tipo_renda  educacao  estado_civil  tipo_residencia  \
# Total de valores missing           0         0             0                0
#
#                           idade  tempo_emprego  possui_celular  \
# Total de valores missing      0              0               0
#
#                           possui_fone_comercial  possui_fone  possui_email  \
# Total de valores missing                      0            0             0
#
#                           qt_pessoas_residencia  mau
# Total de valores missing                      0    0

# %% [markdown]
# **Dados Missing:** na visualizando da estrutura da base de dados já era possível identificar a ausência de dados 'Missing'. Situação confirmada após visualização acima.

# %% [markdown]
# ##### 1.4) Distribuição da variável resposta (mau)

# %%
# Verificando a frequência das categorias na variável 'mau'
df_mau = pd.DataFrame(df['mau'].value_counts())
df_mau['Percentual'] = 100 * df_mau['mau'] / df_linhas
df_mau
# Out:
#          mau  Percentual
# False  16260   97.657658
# True     390    2.342342

# %% [markdown]
# **Análise:** a base de dados não apresenta valores 'Missing' e a quantidade de clientes 'mau' representa 2,34%.

# %% [markdown]
# #### 2) Vamos montar um metadados
#
# 1. Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
# 2. Adicione uma coluna nesse *dataframe* chamada "qtd_categorias" e coloque nela o número de categorias correspondente de cada variável.
#     Dica:
#         1. inicie uma lista vazia
#         2. faça um for ao longo dos nomes das variáveis,
#         3. conte o número de categorias dessa variável
#         4. acumule essa informação de 3. na lista que você criou em 1.
#         5. No final, essa lista pode ser atribuída à nossa variável.
# 3. Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}.

# %% [markdown]
# ##### 2.1) Criando o dataframe com os nomes de cada variável e o tipo de dados de cada variável

# %%
df_dtypes = pd.DataFrame(df.dtypes) # Criando DataFrame com o dtypes
df_dtypes.rename(columns = {0: 'tipo_de_dados'}, inplace = True) # Renomeando a colunas com o tipo dos dados
df_dtypes
# Out:
#                       tipo_de_dados
# sexo                         object
# posse_de_veiculo             object
# posse_de_imovel              object
# qtd_filhos                    int64
# tipo_renda                   object
# educacao                     object
# estado_civil                 object
# tipo_residencia              object
# idade                       float64
# tempo_emprego               float64
# possui_celular                int64
# possui_fone_comercial         int64
# possui_fone                   int64
# possui_email                  int64
# qt_pessoas_residencia       float64
# mau                            bool

# %% [markdown]
# ##### 2.2) Adicionando uma coluna nesse dataframe chamada "qtd_categorias"

# %%
df_nunique = pd.DataFrame(df.nunique()) # Criando DataFrame com o nunique()
df_nunique.rename(columns = {0: 'qtd_categorias'}, inplace = True) # Renomeando a colunas com o tipo dos dados
df_nunique
# Out:
#                        qtd_categorias
# sexo                                2
# posse_de_veiculo                    2
# posse_de_imovel                     2
# qtd_filhos                          8
# tipo_renda                          5
# educacao                            5
# estado_civil                        5
# tipo_residencia                     6
# idade                            5298
# tempo_emprego                    3005
# possui_celular                      1
# possui_fone_comercial               2
# possui_fone                         2
# possui_email                        2
# qt_pessoas_residencia               9
# mau                                 2

# %%
# Concatenando as colunas dos DataFrame
df_metadados = pd.concat([df_dtypes, df_nunique['qtd_categorias']], axis = 1)
df_metadados
# Out:
#                       tipo_de_dados  qtd_categorias
# sexo                         object               2
# posse_de_veiculo             object               2
# posse_de_imovel              object               2
# qtd_filhos                    int64               8
# tipo_renda                   object               5
# educacao                     object               5
# estado_civil                 object               5
# tipo_residencia              object               6
# idade                       float64            5298
# tempo_emprego               float64            3005
# possui_celular                int64               1
# possui_fone_comercial         int64               2
# possui_fone                   int64               2
# possui_email                  int64               2
# qt_pessoas_residencia       float64               9
# mau                            bool               2

# %% [markdown]
# ##### 2.3) Criando função variáveis dummy para as variáveis necessárias

# %%
def convert_dummy(df, variavel):
    df_dummy = pd.get_dummies(df[variavel], prefix = variavel) # Gerando as colunas 'dummy'
    df.drop([variavel],axis=1,inplace=True) # Excluíndo coluna que gerou as colunas 'dummy'
    df=df.join(df_dummy) # Incluíndo as colunas do DataFrame 'pos' ao 'df'
    return df

# %% [markdown]
# #### 3) Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}. Crie um *dataframe* apenas com as variáveis apropriadas para entrada no scikitlearn - elimine as variáveis tipo *str*, mantendo apenas suas versões *dummy*.

# %%
# Gerando as variáveis dummy para as variáveis do tipo de dados igual a 'object'
for var in df_metadados[df_metadados['tipo_de_dados'] == 'object'].index:
    df = convert_dummy(df, var)

# %%
# Visualizando o Dataframe
df.head()
# Out:
#    qtd_filhos      idade  tempo_emprego  possui_celular  \
# 0           0  58.832877       3.106849               1
# 1           0  52.356164       8.358904               1
# 2           0  52.356164       8.358904               1
# 3           0  46.224658       2.106849               1
# 4           0  29.230137       3.021918               1
#
#    possui_fone_comercial  possui_fone  possui_email  qt_pessoas_residencia  \
# 0                      0            0             0                    2.0
# 1                      0            1             1                    1.0
# 2                      0            1             1                    1.0
# 3                      1            1             1                    2.0
# 4                      0            0             0                    2.0
#
#      mau  sexo_F  ...  estado_civil_Married  estado_civil_Separated  \
# 0  False       0  ...                     1                       0
# ...

# %%
# Analisando as variáveis geradas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 36 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   qtd_filhos                              16650 non-null  int64
#  1   idade                                   16650 non-null  float64
#  2   tempo_emprego                           16650 non-null  float64
#  3   possui_celular                          16650 non-null  int64
#  4   possui_fone_comercial                   16650 non-null  int64
#  5   possui_fone                             16650 non-null  int64
#  6   possui_email                            16650 non-null  int64
#  7   qt_pessoas_residencia                   16650 non-null  float64
#  8   mau                                     16650 non-null  bool
#  9   sexo_F                                  16650 non-null  uint8
# ...

# %% [markdown]
# **Análise:** considerando que para as variáveis 'sexo', 'posse_de_veiculo' e 'posse_de_imovel' há apenas duas opções possíveis podemos excluir uma das opções. Sendo assim, vamos excluir as variáveis dummy 'sexo_F', 'posse_de_veiculo_N' e 'posse_de_imovel_N'.

# %%
# Excluíndo as variáveis dummy 'sexo_F', 'posse_de_veiculo_N' e 'posse_de_imovel_N'.
df.drop(['sexo_F'],axis=1,inplace=True)
df.drop(['posse_de_veiculo_N'],axis=1,inplace=True)
df.drop(['posse_de_imovel_N'],axis=1,inplace=True)

# %%
# Visualizando a estrutura do DataFrame 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16650 entries, 0 to 16649
# Data columns (total 33 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   qtd_filhos                              16650 non-null  int64
#  1   idade                                   16650 non-null  float64
#  2   tempo_emprego                           16650 non-null  float64
#  3   possui_celular                          16650 non-null  int64
#  4   possui_fone_comercial                   16650 non-null  int64
#  5   possui_fone                             16650 non-null  int64
#  6   possui_email                            16650 non-null  int64
#  7   qt_pessoas_residencia                   16650 non-null  float64
#  8   mau                                     16650 non-null  bool
#  9   sexo_M                                  16650 non-null  uint8
# ...

# %% [markdown]
# #### 4) Qual variável é mais poderosa?
#
# Considere as variáveis ```possui_email``` e ```posse_de_veiculo```. Faça uma tabela cruzada entre elas e responda qual delas te parece mais poderosa para prever a probabilidade de ```mau = 1```?

# %%
# Tabela cruzada
freq = pd.crosstab(df['possui_email'], df['posse_de_veiculo_Y'])
freq
# Out:
# posse_de_veiculo_Y     0     1
# possui_email
# 0                   9341  5829
# 1                    837   643

# %%
# Calculando os percentuais de linha
freq_pctlin = freq.div(freq.sum(axis = 1), axis = 0) * 100
freq_pctlin
# Out:
# posse_de_veiculo_Y          0          1
# possui_email
# 0                   61.575478  38.424522
# 1                   56.554054  43.445946

# %%
# Calculando os percentuais de coluna
freq_pctcol = freq.div(freq.sum(axis = 0), axis = 1) * 100
freq_pctcol
# Out:
# posse_de_veiculo_Y         0          1
# possui_email
# 0                   91.77638  90.064895
# 1                    8.22362   9.935105

# %% [markdown]
# **Análise:** A variável 'possui_email' me parece mais poderosa, pois a ausência do e-mail representa 91,77% dos clientes que não possuem veículos e 90,06% dos clientes que possuem veículos.

# %% [markdown]
# #### 5) Salve a base, pois ela será utilizada no final deste módulo.

# %%
# Salvando os dados em um arquivo tipo 'csv'
df.to_csv('demo01_dummy.csv')
